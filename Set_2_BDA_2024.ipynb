# %% [markdown]
# <a href="https://colab.research.google.com/github/niladribanerjee80/DSA-Class/blob/main/Set_2_BDA_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Important Guidelines:
#
# 1. DO NOT change
#         (a) function names
#         (b) class names
#         (c) any code that is already given
# You will need to copy the exact code given. Look for # Your code section to write your code
#
# 2. Submit the code file into Google classroom at the end of the exam.
# 3. Feel free to use sheets to draw diagrams, write pseudo-code that may be required
# 4. Some Test cases / Example usages are already given, please feel free to add more test cases if you want below the problem statement.

# %% [markdown]
# # Q1: General Python programming (10 marks)

# %% [markdown]
# Problem Statement: Write a function to find the longest common prefix string amongst an array of strings.
#
# If there is no common prefix, return an empty string "".<br><br>
#
# Example 1:
#
# Input: strs = ["flower","flow","flight"]
#
# Output: "fl" <br><br>
#
#
# Example 2:
#
# Input: strs = ["dog","racecar","car"]
# Output: ""
#
# Explanation: There is no common prefix among the input strings.

# %% [markdown]
# **Hints:**
#
# Input: strs = ["flower","flow","flight"]
#
# If you sort the list,
#
# first word =  flight<br>
# last word =  flower <br>
#
# All you need to do is compare the first and last words. which is = fl
#
# You do not need to even check any words in between. Think about it.<br><br>
#
#
# Try thinking about another list strs = ["flower","fax","flight"]
#
# Sort the list, you will get
#
# first word =  fax<br>
# last word =  flower
#
# The common prefix will be between the first and last words again. which is = f <br><br>
#
#
# Try thinking about another list strs = ["flower","golf","flight"]
#
# Sort the list, you will get
#
# first word =  flight<br>
# last word =  golf
#
# The common prefix will be between the first and last words again. which is None
#
#
# Traversing a string can happen using index = i using a while loop and comparison between them
#
# ```
# i = 0
# while i < len(first) and i < len(last) and first[i] == last[i]:
#     i += 1
# ```

# %%
def longest_common_prefix(strs):
    # Your code
    # strs will be a list like ["flower","flow","flight"] or ["flower","golf","flight"]
    # your program should return the longest common prefix
    pass

# %% [markdown]
# # Q1: Test cases

# %%
# Test cases
# strings = ["flower", "flow", "flight"]
# result = longest_common_prefix(strings)
# print(f"The longest common prefix is: '{result}'") # Output = The longest common prefix is: 'fl'

# %% [markdown]
# # Q2: General Python Programming (10 marks)

# %% [markdown]
# Problem Statement: Write a function to return median of a list of integers
#
# Example:
#
# Input: [1,2,3]
# Output: 2
#
# Input: [1,2,3,4]
# Output: 2.5
# median is (2 + 3) / 2 = 2.5
#
# Note: The input may not always be given in sorted way.

# %%
def median(nums):
    # your code
    pass

# %%
# Test cases
# median([1,4,3,2]) # Output = 2.5
# median([1,2,3,4]) # Output = 2.5
# median([1,2,3,4,5]) # Output = 3

# %% [markdown]
# # Q3: General Python Programming and Double Linked List (10 marks)
#
# Problem Statement: Write a Python program to create a doubly linked list where each node contains a dictionary with key-value pairs. Implement methods to merge all dictionaries into a single dictionary and then sort this dictionary by its keys.

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.prev = None
        self.next = None

class DoubleLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0

    def print_list(self,msg="Print DLL"):
        # verify the code in case required
        print("--------")
        print(msg)
        print("--------")
        if self.length == 0:
            return "Nothing to display"

        temp = self.head
        print("Start", end=" -> ")
        while temp is not None:
            if temp != self.tail:
                print(temp.value, end = " <-> ")
            else:
                print(temp.value, end = " -> ")
            temp = temp.next

        print("End")
        print("\n")

    def append(self, data):
        # Your code here
        pass

    def merge_and_sort(self):
        # Your code here
        # Hints – Think about using standard list functions to achieve your goal.
        pass

# %% [markdown]
# # Q3: Test cases

# %%
# Test cases:
# list = DoubleLinkedList()
# list.append({'a': 1, 'c': 3})
# list.append({'b': 2, 'd': 4})
# list.merge_and_sort()  # Output: {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %% [markdown]
# # Q4: Single Linked List and Stacks (10 marks)
#
# Problem Statement: Implement a single linked list and use it to simulate a stack that can also perform the get_min operation, which returns the minimum element in the stack in O(1) time.

# %% [markdown]
# Hints:
#
# Build the stack
#
# Stack View: 7(top) -> 3 -> 5
#
# min_stack = [keep min value of what is being pushed inside stack]

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

class SLLStack:
    def __init__(self):
        self.top = None
        self.height = 0
        self.min_stack = []

    def push(self, value):
        # Your code
        pass

    def pop(self):
        # Your code
        pass

    def get_min(self):
        # Your code
        pass

# %% [markdown]
# # Q4: Test cases

# %%
# Test cases:
# stack = SingleLinkedListStack()
# stack.push(5)
# stack.push(3)
# stack.push(7)
# print(stack.get_min())  # Output: 3

# %% [markdown]
# # Q5: Binary Search Trees (10 marks)
#
# Problem Statement: Implement delete_node for Binary search tree using recursion technique.
# Rules for deletion
#
# 1. If there is no subtree for a specific node, delete the node
#
# ![image.png](data:image/png;base64,...)
#
#
# 2. left subtree = present, but no right subtree
#
# ![image.png](data:image/png;base64,...)
#
# 3. right subtree = present, but no left subtree
#
# ![image.png](data:image/png;base64,...)
#
# 4. both right and left subtree present. Find the min value from the right subtree and replace the node value and delete the min value node from right side subtree
#
# ![image.png](data:image/png;base64,...)

# %%
class Node:
    def __init__(self,value):
        self.value = value
        self.left = None
        self.right = None

class BST:
    def __init__(self):
        self.root = None

    def r_contains(self,value):
        return self.__r_contains(self.root,value)

    def __r_contains(self,curr_node,value):
        if curr_node == None:
            return False

        if curr_node.value == value:
            return True

        if value < curr_node.value:
            return self.__r_contains(curr_node.left,value)
        else:
            return self.__r_contains(curr_node.right,value)

    def r_insert(self,value):
        if self.root == None:
            self.root = Node(value)
        else:
            self.__r_insert(self.root,value)

    def __r_insert(self,curr_node,value):
        if curr_node == None:
            return Node(value)

        if value < curr_node.value:
            curr_node.left = self.__r_insert(curr_node.left,value)
        elif value > curr_node.value:
            curr_node.right = self.__r_insert(curr_node.right,value)
        else:
            return None
        return curr_node

    def r_delete_node(self,value):
        # Your code here = call the private method = __delete_node
        # ensure you include the code for root deletion as well.
        pass

    def __delete_node(self,curr_node,value):
        # your code here
        pass

    def sub_tree_min(self,curr_node):
        # your code here
        pass

# %% [markdown]
# # Q5: Test cases

# %%
# Test case 1:
my_tree = BST()
my_tree.r_insert(47)
my_tree.r_insert(21)
my_tree.r_insert(18)
my_tree.r_insert(27)
my_tree.r_insert(25)
my_tree.r_insert(24)
my_tree.r_insert(26)
my_tree.r_insert(29)
my_tree.r_insert(28)
my_tree.r_insert(30)
my_tree.r_insert(76)
my_tree.r_insert(53)
my_tree.r_insert(82)

my_tree.r_delete_node(27)

# The above usage is for the most generic case when both left and right subtrees are available for node = 27.
# You may create test cases to show the other scenarios as well.

# %% [markdown]
# End !!
